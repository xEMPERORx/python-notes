# %% [markdown]
# # **Variables**
#
# - variables are just a storage container which help to store the data for to use it during the program
# - In python variables represent the named location which refer to the value of that variable
#
# ## **How are value assigned to the variable**
# In python the value is assigned with the help of assignment operator '='. this operator takes the value to the right and assign it to the left of the operator

# %%
Name="xEMPERORx"
Age= 20
print(Name)
print(Age)
# Out:
# xEMPERORx
# 20

# %% [markdown]
# ## **Naming a variable**
#
# **variable can contain**
# - Letters,
# - numbers,
# - underscore,
#
# + variable cannot contain spaces
# + variable cannot start with a number
# + variable are case sensitive

# %%
_ss213=23 #valid
Name_2="Ap" #valid
2isp=24 #invalid
ip 24 _=34 #invalid
# Out:
# <>:3: SyntaxWarning: invalid decimal literal
# <>:3: SyntaxWarning: invalid decimal literal
# C:\Users\patel\AppData\Local\Temp\ipykernel_16916\3982325184.py:3: SyntaxWarning: invalid decimal literal
#   2isp=24 #invalid
#   Cell In[2], line 3
#     2isp=24 #invalid
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### **Python variable in memory**
#
# #### **so in python the memory are stored in different way let's understand**
#
# - In language like c, c++, java the variable are contain in the form of storage containers when you create a new variable the new storage container is created with that value and the name of that variable. Such as when we reassign a new value to the old variable the value of the vairable gets changed but the storage location remain same for it
#
# - so in python things are different. Here the variable are not like new storage containers these variables donot have fixed locations. The locations they refer to changes every time their value changes
#
# - If we give a command like enroll=22 so the python preloads some commanly used values in an area of memory . as we give that command to that python if a memory location with the value 22 is present enroll will point to that memory location and if we change the value it will do the same , if the value is not in that area of memory then it will create a new memory location with the value 22 in it and enroll will be made to point to that memomry location.

# %%
x= 20
y = 23
print(id(x))
print(id(y))

x= 23
print(id(x))
# Out:
# 140725216594968
# 140725216595064
# 140725216595064

# %% [markdown]
# ## **Data Types**
#
# #### **Introduction**
# Data types are the classification or categorization of data items. Data types
# represent a kind of value that determines what operations can be performed on
# that data. Numeric, non-numeric, and Boolean (true/false) data are the most used
# data types. However, each programming language has its classification largely
# reflecting its programming philosophy.
# **Python offers the following built-in data types:**
# + Numbers
#     + Integers
#     + Floating Point Numbers
#     + Complex Numbers
# + Strings
# + Boolean Values
# + List
# + Tuple
# + Dictionary
#
# #### Type Code Description Default Size (In Bytes)
# - int Integers - 4
# - float Floating - 4
# - bool Boolean - 1
#
# **Note:-**
# - If a variable has been assigned a value of some data type. It can be reassigned a value belonging to some other Data Type in the future.
#
# - **We can use type function to know what class that variable belongs too type().**

# %%
a= "Raw" # String Data Type
print(type(a))
a= 10 # Integer Data Type
print(type(a))
a= 5.6 # Floating Point Number Data Type
print(type(a))
a= 1+8j # Complex Number
print(type(a))
a= True # Boolean Value
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>

# %% [markdown]
# ## **Python Numbers**
#
# #### Introduction
# Number data types store numerical values. Python supports Integers, floating-point
# numbers, and complex numbers. They are defined as int, float, and complex classes.
#
# + Integers can be of any length (Only limited by the memory available). They do not
# have a decimal point and can be positive or negative.
# + A floating-point number is a number having a fractional part. The presence of a
# decimal point indicates a floating-point number. They have a precision of up to 15
# digits.
# + 1 is an integer, 1.0 is a floating-point number.
# + Complex numbers are of the form, x + yj, where x is the real part and y is the
# imaginary part.
#
# **We can use the type() function to know which class a variable or a value belongs to.Similarly, the isinstance() function is used to check if an object belongs to a particular class**
#
# #### **Imp note**
#
# **As we have seen above that how python variable in memory so we have seen that when we assign a variable to a number that already exist in memory then the python will made the variable to point to that same address of that value number but that is only in the case of number lie in between -5 to 256 as we go beyond this limit it might change the address for the same value.**

# %%
b = 5
print(b, "is of type", type(b))
b = 2.0
print(b, "is of type", type(b))
b = 1+2j
print(b, "is complex number?", isinstance(b,complex))

x=10000
y=10000

print(id(x))
print(id(y))
# Out:
# 5 is of type <class 'int'>
# 2.0 is of type <class 'float'>
# (1+2j) is complex number? True
# 2371545955376
# 2371545955216

# %% [markdown]
# ### **Arithmetic operator**
# so these are the operator in python which are responsible for all the arithmetic operations in the program
# so in python there are some differnt arithmetic operator other than the c,c++,java.
#
# #### arithmetic operator are as follow :-
# - '+' Add two operand
# - '-' subtract two operand
# - '*' multiply two operand
# - '/' divide the operand this .We can also say as floating point division
# - '%' modulas it will give the remainder
# - '//' this is interger division so it will give the interger part of the answer
# - ** exponatation this operator will be the first operand raised to the second operand . x**y or x^y x to the power y

# %%
a = 85
b = 95

print(a+b) #add
print(a-b) #subtract
print(a*b) #multiply
print(a/b) #divide
print(a%b) #remainder or modulas
print(a//b) #integer divide
print(a**b) #exponent of a^b
# Out:
# 180
# -10
# 8075
# 0.8947368421052632
# 85
# 0
# 1971505272456843081607568266142587983926751758888229957416912914764407999693562059990570894287545459757397782576880410632815740786954392184155034073445023068416048772633075714111328125

# %% [markdown]
# ## **Input**
#
# so as far now we have only given the input as from our side but in the real world we have to take input from the user so in python we use input() finction to take the input from the user syntax of the input can be this way the program will be in execution untill the user dont give the input to the program.
# - variable_name = input()
# - variable_name = input(promt to display while taking input )

# %%
input()
a = input()
print(a)
a = input('whats your age ? ')
print(a)
# Out:
# 2
# 3

# %% [markdown]
# **So above we have seen how the input function is working here so it have some problem .So lets take a look with a example to add two number where we are taking input form the user**

# %%
a = input()
b = input()
sum=a+b
print(sum)
print(type(sum))
# Out:
# 55
# <class 'str'>

# %% [markdown]
# **So in the above program we have seen how the sum variable have not given the perfect output of 10 insted of that it have give 55 and also the type of that is also str so from here we can say that the input() takes input in form of the string so above ther it have concate the string and given the ouput 55**
#
# ### **To resolve the above problem**
# + we can use the typecast to change the data type of the input and pass that to the sum so then we can get the proper addition
#     + int(typecast_variable)
#     + float(typecast_vairable)
# + so this way we can change the data type from one to another
#
# + here also if we give a complex number to typecast to int or float then it will pass error or we give input like 56d then also it will give error for both the data type

# %%
a = '56'
print(type(a))
b = int(a)
print(type(b))
a= '56d'
print(int(a))
# Out:
# <class 'str'>
# <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       4 print(type(b))
#       5 a= '56d'
# ----> 6 print(int(a))
#
# ValueError: invalid literal for int() with base 10: '56d'

# %%
# so lets direct the process of taking input in just one line
a = int(input('enter the first number '))
b = int(input('enter the second number '))

sum = a+b

print(sum)
# Out:
# 5
