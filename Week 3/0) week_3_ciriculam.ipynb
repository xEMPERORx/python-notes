# %% [markdown]
# ## **Week 3**
# ### **From the previous weeks basic and some important python topics were covered so from here onwards we will be focusing on the data analysis with python and some advance feature of python with working with database such as Sqlite3.**
